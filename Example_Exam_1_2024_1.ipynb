# %%
import numpy as np
import utilities as utl
import matplotlib.pyplot as plt

# %%
reactants = np.array([["CH4 (g, methane)", 1], ["O2(g)", 2]])
products = np.array([["H2O(g)", 2], ["CO2(g)", 1]])

# %%
dG_f0, dH_f0, dS0, vi, K_y, r_298K, p_298K = utl.standard_properties(reactants, products)
# Out:
# Reactant Properties:
#                Species  DHf°[kJ/mol]  S°[J/K·mol]  DGf°[kJ/mol]  Coefficient  \
# 47   CH4 (g, methane)        -74.81      186.264        -50.72          1.0
# 142             O2(g)          0.00      205.138          0.00          2.0
#
#      Weighted_DHf  Weighted_DGf  Weighted_S      n [mol]  \
# 47         -74.81        -50.72     186.264  1.0 - 1.0*x
# 142          0.00          0.00     410.276  2.0 - 2.0*x
#
#                                          y_i
# 47   0.333333333333333 - 0.333333333333333*x
# 142  0.666666666666667 - 0.666666666666667*x
#
# Product Properties:
#     Species  DHf°[kJ/mol]  S°[J/K·mol]  DGf°[kJ/mol]  Coefficient  \
# 63  CO2(g)      -393.509      213.740      -394.359          1.0
# 90  H2O(g)      -241.818      188.825      -228.572          2.0
#
#     Weighted_DHf  Weighted_DGf  Weighted_S      n [mol]  \
# 63      -393.509      -394.359      213.74  1.0 - 1.0*x
# 90      -483.636      -457.144      377.65  2.0 - 2.0*x
#
#                                         y_i
# 63  0.333333333333333 - 0.333333333333333*x
# 90  0.666666666666667 - 0.666666666666667*x
#
# ΔG°: -800.7829999999999 kJ/mol, spontaneous.
# ΔH°: -802.335 kJ/mol, exothermic.
# ΔS°: -0.005205433506624634 kJ/(K·mol), decreased disorder.
# ln(K_a): 323.05019757190024
# K_a: 1.9902983512178686e+140
# K_y: 1.00000000000000
# Net Stoichiometric Coefficient (v_i): 0.0

# %%
temperatures = np.array([350, 500, 600, 800, 1000, 1200, 1500])
results = utl.properties_temperature(temperatures, dH_f0, dS0)
# Out:
#    Temperature (K)  ΔG° (kJ/mol)     ln(K_a)            K_a
# 0              350   -800.513098  275.099865  2.980942e+119
# 1              500   -799.732283  192.382074   3.552003e+83
# 2              600   -799.211740  160.214045   3.802555e+69
# 3              800   -798.170653  120.004007   1.309418e+52
# 4             1000   -797.129566   95.877985   4.357925e+41
# 5             1200   -796.088480   79.793970   4.509006e+34
# 6             1500   -794.526850   63.709955   4.665325e+27

# %%
utl.graphs(results)
