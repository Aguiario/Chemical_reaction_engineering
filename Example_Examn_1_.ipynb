# %%
import numpy as np
import pandas as pd
import utilities as utl

# %%
reactants = np.array([["C2H5OH(l, ethanol)", 1], ["O2(g)", 3]])
products = np.array([["H2O(l)", 3], ["CO2(g)", 2]])

# %%
dG_f0, dH_f0, dS0, vi, K_y, r_298K, p_298K = utl.standard_properties(reactants, products)
# Out:
# Reactant Properties:
#     Species  DHf°[kJ/mol]  S°[J/K·mol]  DGf°[kJ/mol]  Coefficient  \
# 63  CO2(g)      -393.509       213.74      -394.359          2.0
# 89  H2O(l)      -285.830        69.91      -237.129          3.0
#
#     Weighted_DHf  Weighted_DGf  Weighted_S      n [mol]          y_i
# 63      -787.018      -788.718      427.48  2.0 - 2.0*x  0.4 - 0.4*x
# 89      -857.490      -711.387      209.73  3.0 - 3.0*x  0.6 - 0.6*x
#
# Product Properties:
#     Species  DHf°[kJ/mol]  S°[J/K·mol]  DGf°[kJ/mol]  Coefficient  \
# 63  CO2(g)      -393.509       213.74      -394.359          2.0
# 89  H2O(l)      -285.830        69.91      -237.129          3.0
#
#     Weighted_DHf  Weighted_DGf  Weighted_S n [mol]    y_i
# 63      -787.018      -788.718      427.48   2.0*x  0.4*x
# 89      -857.490      -711.387      209.73   3.0*x  0.6*x
#
# ΔG°: 0.0 kJ/mol, spontaneous.
# ΔH°: 0.0 kJ/mol, exothermic.
# ΔS°: 0.0 kJ/(K·mol), decreased disorder.
# ln(K_a): -0.0
# K_a: 1.0
# K_y: 1.0*(1 - x)**5.0/x**5.0
# Net Stoichiometric Coefficient (v_i): 0.0
# Total number of moles (n_t): 5.00000000000000

# %%
temperatures = np.array([350, 500, 600, 800, 1000, 1200, 1500])
results = utl.properties_temperature(temperatures, dG_f0, dS0)
# Out:
#    Temperature (K)  ΔG° (kJ/mol)  ln(K_a)  K_a
# 0              350           0.0     -0.0  1.0
# 1              500           0.0     -0.0  1.0
# 2              600           0.0     -0.0  1.0
# 3              800           0.0     -0.0  1.0
# 4             1000           0.0     -0.0  1.0
# 5             1200           0.0     -0.0  1.0
# 6             1500           0.0     -0.0  1.0

# %%
utl.graphs(results)
