# %%
import numpy as np
import utilities as utl
from sympy import symbols, Eq, solve

# %%
temperatures = valores = np.linspace(300, 1500, num=12)

# %%
reactants_1 = np.array([["C(s, graphite)", 1], ["H2O(g)", 1]])
products_1 = np.array([["H2(g)", 1], ["CO(g)", 1]])

dG_f0_1, dH_f0_1, dS0_1, vi_1, K_y_1, r_298K_1, p_298K_1 = utl.standard_properties(reactants_1, products_1)
x = symbols('x')
K_y_1 = 1/K_y_1
results_1 = utl.properties_temperature(temperatures, dG_f0_1, dS0_1, K_y=K_y_1)

utl.graphs(results_1)
# Out:
# Reactant Properties:
#             Species  DHf°[kJ/mol]  S°[J/K·mol]  DGf°[kJ/mol]  Coefficient  \
# 40  C(s, graphite)         0.000        5.740         0.000          1.0
# 90          H2O(g)      -241.818      188.825      -228.572          1.0
#
#     Weighted_DHf  Weighted_DGf  Weighted_S      n [mol]          y_i
# 40         0.000         0.000       5.740  1.0 - 1.0*x  0.5 - 0.5*x
# 90      -241.818      -228.572     188.825  1.0 - 1.0*x  0.5 - 0.5*x
#
# Product Properties:
#     Species  DHf°[kJ/mol]  S°[J/K·mol]  DGf°[kJ/mol]  Coefficient  \
# 62   CO(g)      -110.525      197.674      -137.168          1.0
# 86   H2(g)         0.000      130.684         0.000          1.0
#
#     Weighted_DHf  Weighted_DGf  Weighted_S n [mol]    y_i
# 62      -110.525      -137.168     197.674   1.0*x  0.5*x
# 86         0.000         0.000     130.684   1.0*x  0.5*x
#
# ΔG°: 91.404 kJ/mol, non-spontaneous.
# ΔH°: 131.293 kJ/mol, endothermic.
# ΔS°: 0.1337883615629717 kJ/(K·mol), increased disorder.
# ln(K_a): -36.874009886401154
# K_a: 9.678788074136701e-17
# K_y: 1.0*(1 - x)**2.0/x**2.0
# Net Stoichiometric Coefficient (v_i): 0.0
# Total number of moles (n_t): 2.00000000000000
#     Temperature (K)  ΔG° (kJ/mol)    ln(K_a)           K_a  \
# 0        300.000000     51.267492 -20.554683  1.183626e-09
# 1        409.090909     36.672398 -10.782251  2.076480e-05
# 2        518.181818     22.077304  -5.124528  5.949027e-03
# 3        627.272727      7.482210  -1.434708  2.381850e-01
# 4        736.363636     -7.112884   1.161832  3.195783e+00
# 5        845.454545    -21.707978   3.088297  2.193969e+01
# 6        954.545455    -36.303072   4.574427  9.697251e+01
# 7       1063.636364    -50.898166   5.755710  3.159900e+02
# 8       1172.727273    -65.493260   6.717220  8.265165e+02
# 9       1281.818182    -80.088354   7.515068  1.835493e+03
# 10      1390.909091    -94.683448   8.187764  3.596670e+03
# 11      1500.000000   -109.278542   8.762613  6.390787e+03
#
#                       X
# 0   3.44026781875460e-5
# 1   0.00453617012543826
# 2    0.0716068995544738
# 3     0.327975944378846
# 4     0.641278170405324
# 5     0.824067005538060
# 6     0.907812536070254
# 7     0.946740822758449
# 8     0.966385650939097
# 9     0.977191158962607
# 10    0.983599094654775
# 11    0.987645534969688

# %%
reactants_2 = np.array([["C(s, graphite)", 1], ["H2O(g)", 2]])
products_2 = np.array([["H2(g)", 2], ["CO2(g)", 1]])

dG_f0_2, dH_f0_2, dS0_2, vi_2, K_y_2, r_298K_2, p_298K_2 = utl.standard_properties(reactants_2, products_2)
K_y_2 = 1/K_y_2
results_2 = utl.properties_temperature(temperatures, dG_f0_2, dS0_2, K_y=K_y_2)
# Out:
# Reactant Properties:
#             Species  DHf°[kJ/mol]  S°[J/K·mol]  DGf°[kJ/mol]  Coefficient  \
# 40  C(s, graphite)         0.000        5.740         0.000          1.0
# 90          H2O(g)      -241.818      188.825      -228.572          2.0
#
#     Weighted_DHf  Weighted_DGf  Weighted_S      n [mol]  \
# 40         0.000         0.000        5.74  1.0 - 1.0*x
# 90      -483.636      -457.144      377.65  2.0 - 2.0*x
#
#                                         y_i
# 40  0.333333333333333 - 0.333333333333333*x
# 90  0.666666666666667 - 0.666666666666667*x
#
# Product Properties:
#     Species  DHf°[kJ/mol]  S°[J/K·mol]  DGf°[kJ/mol]  Coefficient  \
# 63  CO2(g)      -393.509      213.740      -394.359          1.0
# 86   H2(g)         0.000      130.684         0.000          2.0
#
#     Weighted_DHf  Weighted_DGf  Weighted_S n [mol]                  y_i
# 63      -393.509      -394.359     213.740   1.0*x  0.333333333333333*x
# 86         0.000         0.000     261.368   2.0*x  0.666666666666667*x
#
# ΔG°: 62.785000000000025 kJ/mol, non-spontaneous.
# ΔH°: 90.12700000000001 kJ/mol, endothermic.
# ΔS°: 0.091705517357035 kJ/(K·mol), increased disorder.
# ln(K_a): -25.32859295783223
# K_a: 9.998430774159076e-12
# K_y: 1.0*(1 - x)**3.0/x**3.0
# Net Stoichiometric Coefficient (v_i): 0.0
# Total number of moles (n_t): 3.00000000000000
#     Temperature (K)  ΔG° (kJ/mol)    ln(K_a)           K_a  \
# 0        300.000000     35.273345 -14.142148  7.213454e-07
# 1        409.090909     25.269107  -7.429508  5.934796e-04
# 2        518.181818     15.264868  -3.543242  2.891941e-02
# 3        627.272727      5.260630  -1.008722  3.646849e-01
# 4        736.363636     -4.743608   0.774830  2.170223e+00
# 5        845.454545    -14.747846   2.098110  8.150753e+00
# 6        954.545455    -24.752085   3.118927  2.262208e+01
# 7       1063.636364    -34.756323   3.930345  5.092452e+01
# 8       1172.727273    -44.760561   4.590801  9.857337e+01
# 9       1281.818182    -54.764800   5.138840  1.705178e+02
# 10      1390.909091    -64.769038   5.600911  2.706729e+02
# 11      1500.000000    -74.773276   5.995772  4.017268e+02
#
#                       X
# 0   0.00888867179525271
# 1    0.0775219421387423
# 2     0.234857918165617
# 3     0.416722982127169
# 4     0.564212616040953
# 5     0.668048103689609
# 6     0.738780960110938
# 7     0.787532375747206
# 8     0.822045381676939
# 9     0.847218068789958
# 10    0.866107334234022
# 11    0.880649037206454
